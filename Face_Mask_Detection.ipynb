# %%
import cv2

# %%
img = cv2.imread('C:/Users/HP/Documents/img.jpg')

# %%
img.shape
# Out:
# (330, 259, 3)

# %%
img[0]
# Out:
# array([[ 92,  96,  84],
#        [ 90,  94,  82],
#        [ 86,  90,  78],
#        [ 83,  87,  75],
#        [ 82,  86,  74],
#        [ 82,  86,  74],
#        [ 83,  87,  75],
#        [ 85,  89,  77],
#        [ 96,  96,  84],
#        [ 96,  96,  84],
#        [ 95,  95,  83],
#        [ 93,  93,  81],
#        [ 91,  91,  79],
#        [ 90,  90,  78],
#        [ 89,  89,  77],
#        [ 88,  88,  76],
#        [ 92,  92,  80],
#        [ 93,  93,  81],
#        [ 93,  93,  81],
#        [ 93,  93,  81],
#        [ 94,  94,  82],
#        [ 95,  95,  83],
#        [ 95,  95,  83],
#        [ 95,  95,  83],
#        [ 98,  97,  83],
#        [100,  99,  85],
#        [104, 103,  89],
#        [106, 105,  91],
#        [107, 106,  92],
#        [105, 104,  90],
#        [102, 101,  87],
#        [100,  99,  85],
#        [100, 103,  81],
#        [100, 103,  81],
#        [100, 103,  81],
#        [ 99, 102,  80],
#        [ 99, 102,  80],
#        [ 98, 101,  79],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow('final',img)
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-422de0c10ca0> in <module>
#       1 while True:
# ----> 2     cv2.imshow('final',img)
#       3     if cv2.waitKey(2) == 27:
#       4         break
#       5 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined
